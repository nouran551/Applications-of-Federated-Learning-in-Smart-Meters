# %% [markdown]
# https://gist.github.com/saranshmanu/3e2807409a2838a3e221186ef5528bc7#file-federated_learning-ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install syft==0.2.8
# Out:
# Collecting syft==0.2.8
#   Downloading https://files.pythonhosted.org/packages/69/eb/e7ad7f909c53477f9fbe732aaa5cf036122428268e5239b18344604bc8f8/syft-0.2.8-py3-none-any.whl (415kB)
#      |████████████████████████████████| 419kB 8.8MB/s
# Collecting websockets~=8.1.0
#   Downloading https://files.pythonhosted.org/packages/bb/d9/856af84843912e2853b1b6e898ac8b802989fcf9ecf8e8445a1da263bf3b/websockets-8.1-cp36-cp36m-manylinux2010_x86_64.whl (78kB)
#      |████████████████████████████████| 81kB 7.4MB/s
# Collecting tblib~=1.6.0
#   Downloading https://files.pythonhosted.org/packages/0d/de/dca3e651ca62e59c08d324f4a51467fa4b8cbeaafb883b5e83720b4d4a47/tblib-1.6.0-py2.py3-none-any.whl
# Collecting torch~=1.4.0
#   Downloading https://files.pythonhosted.org/packages/24/19/4804aea17cd136f1705a5e98a00618cb8f6ccc375ad8bfa437408e09d058/torch-1.4.0-cp36-cp36m-manylinux1_x86_64.whl (753.4MB)
#      |████████████████████████████████| 753.4MB 22kB/s
# Collecting psutil==5.7.0
#   Downloading https://files.pythonhosted.org/packages/c4/b8/3512f0e93e0db23a71d82485ba256071ebef99b227351f0f5540f744af41/psutil-5.7.0.tar.gz (449kB)
#      |████████████████████████████████| 450kB 48.8MB/s
# Collecting requests~=2.22.0
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 9.8MB/s
# Collecting torchvision~=0.5.0
#   Downloading https://files.pythonhosted.org/packages/7e/90/6141bf41f5655c78e24f40f710fdd4f8a8aff6c8b7c6f0328240f649bdbe/torchvision-0.5.0-cp36-cp36m-manylinux1_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.0MB 51.1MB/s
# Collecting lz4~=3.0.2
#   Downloading https://files.pythonhosted.org/packages/e7/81/011fef8766fb0ef681037ad6fee96168ee03a864464986cbaa23e5357704/lz4-3.0.2-cp36-cp36m-manylinux2010_x86_64.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 43.6MB/s
# Collecting websocket-client~=0.57.0
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
#      |████████████████████████████████| 204kB 62.4MB/s
# Collecting notebook==5.7.8
#   Downloading https://files.pythonhosted.org/packages/f6/36/89ebfffc9dd8c8dbd81c1ffb53e3d4233ee666414c143959477cb07cc5f5/notebook-5.7.8-py2.py3-none-any.whl (9.0MB)
#      |████████████████████████████████| 9.0MB 19.6MB/s
# Collecting openmined.threepio==0.2.0
#   Downloading https://files.pythonhosted.org/packages/0a/38/df6367693c7f3808f076cd8c2647c434a04adda2bbb2435dadefe7258fd4/openmined.threepio-0.2.0.tar.gz (73kB)
#      |████████████████████████████████| 81kB 13.9MB/s
# Collecting tornado==4.5.3
#   Downloading https://files.pythonhosted.org/packages/e3/7b/e29ab3d51c8df66922fea216e2bddfcb6430fb29620e5165b16a216e0d3c/tornado-4.5.3.tar.gz (484kB)
#      |████████████████████████████████| 491kB 57.5MB/s
# Collecting syft-proto~=0.5.0
#   Downloading https://files.pythonhosted.org/packages/da/88/67edf7836ac4eab723416933cd663c4f87753d3ff31337f91701c0b75474/syft_proto-0.5.3-py3-none-any.whl (66kB)
#      |████████████████████████████████| 71kB 11.6MB/s
# Collecting Pillow~=6.2.2
#   Downloading https://files.pythonhosted.org/packages/8a/fd/bbbc569f98f47813c50a116b539d97b3b17a86ac7a309f83b2022d26caf2/Pillow-6.2.2-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 47.5MB/s
# Collecting RestrictedPython~=5.0
#   Downloading https://files.pythonhosted.org/packages/a0/cc/28c4d966615a46b03be4dac0f2c6e713412efbf2f85428eeb9618c4f6f0c/RestrictedPython-5.1-py2.py3-none-any.whl
# Collecting numpy~=1.18.1
#   Downloading https://files.pythonhosted.org/packages/b3/a9/b1bc4c935ed063766bce7d3e8c7b20bd52e515ff1c732b02caacf7918e5a/numpy-1.18.5-cp36-cp36m-manylinux1_x86_64.whl (20.1MB)
#      |████████████████████████████████| 20.1MB 13.0MB/s
# Requirement already satisfied: dill~=0.3.1 in /usr/local/lib/python3.6/dist-packages (from syft==0.2.8) (0.3.3)
# Requirement already satisfied: Flask~=1.1.1 in /usr/local/lib/python3.6/dist-packages (from syft==0.2.8) (1.1.2)
# Collecting phe~=1.4.0
#   Downloading https://files.pythonhosted.org/packages/32/0e/568e97b014eb14e794a1258a341361e9da351dc6240c63b89e1541e3341c/phe-1.4.0.tar.gz
# Collecting aiortc==0.9.28
#   Downloading https://files.pythonhosted.org/packages/bf/54/beb8dcb9050aaf903c4426884970d0f18a76e49c69b5a06653812e404446/aiortc-0.9.28-cp36-cp36m-manylinux2010_x86_64.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 39.1MB/s
# Collecting importlib-resources~=1.5.0
#   Downloading https://files.pythonhosted.org/packages/7f/2d/88f166bcaadc09d9fdbf1c336ad118e01b7fe1155e15675e125be2ff1899/importlib_resources-1.5.0-py2.py3-none-any.whl
# Collecting requests-toolbelt==0.9.1
#   Downloading https://files.pythonhosted.org/packages/60/ef/7681134338fc097acef8d9b2f8abe0458e4d87559c689a8c306d0957ece5/requests_toolbelt-0.9.1-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 9.7MB/s
# Requirement already satisfied: msgpack~=1.0.0 in /usr/local/lib/python3.6/dist-packages (from syft==0.2.8) (1.0.2)
# Requirement already satisfied: scipy~=1.4.1 in /usr/local/lib/python3.6/dist-packages (from syft==0.2.8) (1.4.1)
# Collecting flask-socketio~=4.2.1
#   Downloading https://files.pythonhosted.org/packages/66/44/edc4715af85671b943c18ac8345d0207972284a0cd630126ff5251faa08b/Flask_SocketIO-4.2.1-py2.py3-none-any.whl
# Collecting idna<2.9,>=2.5
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 10.1MB/s
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests~=2.22.0->syft==0.2.8) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests~=2.22.0->syft==0.2.8) (2020.12.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests~=2.22.0->syft==0.2.8) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision~=0.5.0->syft==0.2.8) (1.15.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from notebook==5.7.8->syft==0.2.8) (4.10.1)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.6/dist-packages (from notebook==5.7.8->syft==0.2.8) (4.3.3)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from notebook==5.7.8->syft==0.2.8) (0.2.0)
# Requirement already satisfied: jupyter-client>=5.2.0 in /usr/local/lib/python3.6/dist-packages (from notebook==5.7.8->syft==0.2.8) (5.3.5)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.6/dist-packages (from notebook==5.7.8->syft==0.2.8) (4.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from notebook==5.7.8->syft==0.2.8) (2.11.2)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from notebook==5.7.8->syft==0.2.8) (0.9.2)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook==5.7.8->syft==0.2.8) (5.6.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.6/dist-packages (from notebook==5.7.8->syft==0.2.8) (0.9.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.6/dist-packages (from notebook==5.7.8->syft==0.2.8) (20.0.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from notebook==5.7.8->syft==0.2.8) (1.5.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.6/dist-packages (from notebook==5.7.8->syft==0.2.8) (5.0.8)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.6/dist-packages (from syft-proto~=0.5.0->syft==0.2.8) (3.12.4)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask~=1.1.1->syft==0.2.8) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask~=1.1.1->syft==0.2.8) (1.0.1)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask~=1.1.1->syft==0.2.8) (7.1.2)
# Collecting pylibsrtp>=0.5.6
#   Downloading https://files.pythonhosted.org/packages/cb/fd/4f8e286da01db4e52aaa6426eac496af6e4dc00419d807d4f87d07363d84/pylibsrtp-0.6.7-cp36-cp36m-manylinux2010_x86_64.whl (75kB)
#      |████████████████████████████████| 81kB 12.8MB/s
# Collecting crc32c
#   Downloading https://files.pythonhosted.org/packages/2f/b4/e2e293d323f10d03929ed2b68de14cdddd523700381de6aecec561f7c2d1/crc32c-2.2-cp36-cp36m-manylinux2010_x86_64.whl (48kB)
#      |████████████████████████████████| 51kB 9.5MB/s
# Collecting pyee>=6.0.0
#   Downloading https://files.pythonhosted.org/packages/0d/0a/933b3931107e1da186963fd9bb9bceb9a613cff034cb0fb3b0c61003f357/pyee-8.1.0-py2.py3-none-any.whl
# Collecting cryptography>=2.2
#   Downloading https://files.pythonhosted.org/packages/c9/de/7054df0620b5411ba45480f0261e1fb66a53f3db31b28e3aa52c026e72d9/cryptography-3.3.1-cp36-abi3-manylinux2010_x86_64.whl (2.6MB)
#      |████████████████████████████████| 2.6MB 45.8MB/s
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiortc==0.9.28->syft==0.2.8) (0.8)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from aiortc==0.9.28->syft==0.2.8) (1.14.4)
# Collecting av<9.0.0,>=8.0.0
#   Downloading https://files.pythonhosted.org/packages/9e/62/9a992be76f8e13ce0e3a24a838191b546805545116f9fc869bd11bd21b5f/av-8.0.2-cp36-cp36m-manylinux2010_x86_64.whl (36.9MB)
#      |████████████████████████████████| 36.9MB 86kB/s
# Collecting aioice<0.7.0,>=0.6.17
#   Downloading https://files.pythonhosted.org/packages/8b/86/e3cdf660b67da7a9a7013253db5db7cf786a52296cb40078db1206177698/aioice-0.6.18-py3-none-any.whl
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-resources~=1.5.0->syft==0.2.8) (3.4.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-resources~=1.5.0->syft==0.2.8) (3.3.0)
# Collecting python-socketio>=4.3.0
#   Downloading https://files.pythonhosted.org/packages/22/76/071fed5787169c45f72e07b64d71c77761326d6b76471d9773fbff634ce7/python_socketio-5.0.4-py2.py3-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 10.8MB/s
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel->notebook==5.7.8->syft==0.2.8) (5.5.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2.1->notebook==5.7.8->syft==0.2.8) (4.4.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client>=5.2.0->notebook==5.7.8->syft==0.2.8) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->notebook==5.7.8->syft==0.2.8) (1.1.1)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /usr/local/lib/python3.6/dist-packages (from terminado>=0.8.1->notebook==5.7.8->syft==0.2.8) (0.7.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.8) (0.6.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.8) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.8) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.8) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.8) (1.4.3)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.8) (2.6.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook==5.7.8->syft==0.2.8) (3.2.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat->notebook==5.7.8->syft==0.2.8) (2.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.12.2->syft-proto~=0.5.0->syft==0.2.8) (51.1.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0.0->aiortc==0.9.28->syft==0.2.8) (2.20)
# Collecting netifaces
#   Downloading https://files.pythonhosted.org/packages/0c/9b/c4c7eb09189548d45939a3d3a6b3d53979c67d124459b27a094c365c347f/netifaces-0.10.9-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->importlib-resources~=1.5.0->syft==0.2.8) (3.7.4.3)
# Collecting python-engineio>=4
#   Downloading https://files.pythonhosted.org/packages/c4/29/efdb97d117b0f6538b046b576e33c1cbd59b4d1c2959cf8d0f8089a8f1b4/python_engineio-4.0.0-py2.py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 9.1MB/s
# Collecting bidict>=0.21.0
#   Downloading https://files.pythonhosted.org/packages/67/d4/eaf9242722bf991e0955380dd6168020cb15a71cc0d3cc2373f4911b1f1d/bidict-0.21.2-py2.py3-none-any.whl
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.8) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.8) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.8) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.8) (0.8.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook==5.7.8->syft==0.2.8) (0.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook==5.7.8->syft==0.2.8) (20.8)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipykernel->notebook==5.7.8->syft==0.2.8) (0.2.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->bleach->nbconvert->notebook==5.7.8->syft==0.2.8) (2.4.7)
# Building wheels for collected packages: psutil, openmined.threepio, tornado, phe
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.7.0-cp36-cp36m-linux_x86_64.whl size=272668 sha256=91bcf1da674267fe9d45323055c1e11240d73cc3ed97500a98f59557fde8f53f
#   Stored in directory: /root/.cache/pip/wheels/d7/69/b4/3200b95828d1f0ddb3cb5699083717f4fdbd9b4223d0644c57
#   Building wheel for openmined.threepio (setup.py) ... done
#   Created wheel for openmined.threepio: filename=openmined.threepio-0.2.0-cp36-none-any.whl size=80096 sha256=3f9c67d0191229fdafb380a131bf2cdd5e1277d1c4b188f7bd9edeac3eb39ced
#   Stored in directory: /root/.cache/pip/wheels/1b/a5/c5/7e67449f5d4d487e1d3a583ba51d27403b315b18ef2e48a13c
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-4.5.3-cp36-cp36m-linux_x86_64.whl size=433074 sha256=8cf9ebaf3a8e303f92c809ed926f45a8c3290d7a801f9c4fd2b7113a65decbd9
#   Stored in directory: /root/.cache/pip/wheels/72/bf/f4/b68fa69596986881b397b18ff2b9af5f8181233aadcc9f76fd
#   Building wheel for phe (setup.py) ... done
#   Created wheel for phe: filename=phe-1.4.0-py2.py3-none-any.whl size=37362 sha256=0037452af650a9cc3b12b8aff42a6d4c1f0f3a233281212106563f4ac51d2002
#   Stored in directory: /root/.cache/pip/wheels/f8/dc/36/dcb6bf0f1b9907e7b710ace63e64d08e7022340909315fdea4
# Successfully built psutil openmined.threepio tornado phe
# ERROR: tensorflow 2.4.0 has requirement numpy~=1.19.2, but you'll have numpy 1.18.5 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement notebook~=5.3.0; python_version >= "3.0", but you'll have notebook 5.7.8 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement requests~=2.23.0, but you'll have requests 2.22.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement tornado~=5.1.0; python_version >= "3.0", but you'll have tornado 4.5.3 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: bokeh 2.1.1 has requirement tornado>=5.1, but you'll have tornado 4.5.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: websockets, tblib, torch, psutil, idna, requests, numpy, Pillow, torchvision, lz4, websocket-client, tornado, notebook, openmined.threepio, syft-proto, RestrictedPython, phe, pylibsrtp, crc32c, pyee, cryptography, av, netifaces, aioice, aiortc, importlib-resources, requests-toolbelt, python-engineio, bidict, python-socketio, flask-socketio, syft
#   Found existing installation: tblib 1.7.0
#     Uninstalling tblib-1.7.0:
#       Successfully uninstalled tblib-1.7.0
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
#   Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Found existing installation: notebook 5.3.1
#     Uninstalling notebook-5.3.1:
#       Successfully uninstalled notebook-5.3.1
#   Found existing installation: importlib-resources 4.1.1
#     Uninstalling importlib-resources-4.1.1:
#       Successfully uninstalled importlib-resources-4.1.1
# Successfully installed Pillow-6.2.2 RestrictedPython-5.1 aioice-0.6.18 aiortc-0.9.28 av-8.0.2 bidict-0.21.2 crc32c-2.2 cryptography-3.3.1 flask-socketio-4.2.1 idna-2.8 importlib-resources-1.5.0 lz4-3.0.2 netifaces-0.10.9 notebook-5.7.8 numpy-1.18.5 openmined.threepio-0.2.0 phe-1.4.0 psutil-5.7.0 pyee-8.1.0 pylibsrtp-0.6.7 python-engineio-4.0.0 python-socketio-5.0.4 requests-2.22.0 requests-toolbelt-0.9.1 syft-0.2.8 syft-proto-0.5.3 tblib-1.6.0 torch-1.4.0 torchvision-0.5.0 tornado-4.5.3 websocket-client-0.57.0 websockets-8.1

# %%
import syft as sy 

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from syft.frameworks.torch.fl import utils

import random
import time
import json
import copy
import os
import glob

# %%
hook = sy.TorchHook(torch)
smart_meter1 = sy.VirtualWorker(hook, id="sm1")
smart_meter2 = sy.VirtualWorker(hook, id="sm2")
compute_nodes = [smart_meter1, smart_meter2]

# %%
class Parser:
    def __init__(self):
        self.epochs = 200
        self.lr = 0.001
        self.test_batch_size = 8                                                # number here is [A] and should be equal to [B]
        self.batch_size = 8
        self.log_interval = 10
        self.seed = 1
        self.no_cuda = False
    
args = Parser()
use_cuda = not args.no_cuda and torch.cuda.is_available()
torch.manual_seed(args.seed)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
device
# Out:
# device(type='cuda')

# %%
path='/content/drive/My Drive/GP | Smart Meter | CIC/Datasets'

# %%
data = pd.read_csv(path + "/sample_data_.csv")

# %%
data = data.drop(['Unnamed: 0','day'], axis = 1)
print(data[:])

# data --> [2:]
# target --> [only second column]
# Out:
#            LCLid  energy_sum  temperatureMax  ...  month  season  year
# 0      MAC001497       4.364           17.77  ...      7       2  2012
# 1      MAC003176      10.340           20.82  ...     10       0  2013
# 2      MAC001679       4.236           27.12  ...      9       0  2012
# 3      MAC001544      13.980           15.87  ...     10       0  2013
# 4      MAC000655       6.663            8.27  ...      3       1  2013
# ...          ...         ...             ...  ...    ...     ...   ...
# 39995  MAC005024       4.794           20.33  ...      6       2  2013
# 39996  MAC002257       3.277           11.00  ...     11       0  2013
# 39997  MAC003571       4.108            7.30  ...      3       1  2013
# 39998  MAC004038       1.269           22.42  ...      8       2  2013
# 39999  MAC004163       7.357           24.62  ...      7       2  2013
#
# [40000 rows x 34 columns]

# %%
features = data.drop(['LCLid','energy_sum'], axis = 1)
features = features.to_numpy()  # inputs <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
target = data[['energy_sum']]
target = target.to_numpy()      # output <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %%
split_frac = 0.8
split_idx= int (len(features)*split_frac)
train_x,test_x = features[:split_idx], features[split_idx:]
train_y,test_y = target[:split_idx], target[split_idx:]

train_y = train_y.ravel()
test_y = test_y.ravel()

print("\t\t\t Feature shapes:")
print("Train set: \t\t{}\n".format(train_x.shape), "Test set: \t\t{}\n".format(test_x.shape))
# Out:
# 			 Feature shapes:
# Train set: 		(32000, 32)
#  Test set: 		(8000, 32)

# %%
train = TensorDataset(torch.from_numpy(train_x).float(), torch.from_numpy(train_y).float())
test = TensorDataset(torch.from_numpy(test_x).float(), torch.from_numpy(test_y).float())
train_loader = DataLoader(train, batch_size=args.batch_size, shuffle=True)
test_loader = DataLoader(test, batch_size=args.test_batch_size, shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(256, 128, bias=True)                                          # this number here is [C] and should be equal to [D]
        self.fc2 = nn.Linear(128, 64, bias=True)
        self.fc3 = nn.Linear(64, 32, bias=True)
        self.fc4 = nn.Linear(32, 16, bias=True)
        self.fc5 = nn.Linear(16, 8, bias=True)                                          # this number here is [B] and should be equal to [A]

    def forward(self, x):
        # print(x.shape)  # (8, 32) --> 1D vector of 8*32 = 256
        x = x.view(-1, 256)                                                     # this number here is [D] and should be equal to [C]
        x = F.leaky_relu(self.fc1(x))
        x = F.relu_(self.fc2(x))
        x = F.relu6(self.fc3(x))
        x = F.rrelu(self.fc4(x))
        x = torch.tanh(self.fc5(x)) #self.fc6(x)
        return x

# %% [markdown]
# Though data will be available offline for federated learning with the workers but here we are sending the data over to the workers for training with ondevice capability

# %%
remote_dataset = (list(), list())
train_distributed_dataset = []

for batch_idx, (data,target) in enumerate(train_loader):
    data = data.send(compute_nodes[batch_idx % len(compute_nodes)])
    target = target.send(compute_nodes[batch_idx % len(compute_nodes)])
    remote_dataset[batch_idx % len(compute_nodes)].append((data, target))

# %%
smart_meter1_model = Net()
smart_meter2_model = Net()
smart_meter1_optimizer = optim.SGD(smart_meter1_model.parameters(), lr=args.lr)
smart_meter2_optimizer = optim.SGD(smart_meter2_model.parameters(), lr=args.lr)

# %%
models = [smart_meter1_model, smart_meter2_model]
optimizers = [smart_meter1_optimizer, smart_meter2_optimizer]

# %%
model = Net()
model
# Out:
# Net(
#   (fc1): Linear(in_features=256, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=16, bias=True)
#   (fc5): Linear(in_features=16, out_features=8, bias=True)
# )

# %%
def update(data, target, model, optimizer):
    model.send(data.location)
    optimizer.zero_grad()
    prediction = model(data)
    loss = F.mse_loss(prediction.view(-1), target)
    # print('prediction', prediction.view(-1).shape)                              # this number here is [E] and should be equal to [F]
    # print('target', target.shape)                                               # this number here is [F] and should be equal to [E]
    loss.backward()
    optimizer.step()
    return model

def train():
    for data_index in range(len(remote_dataset[0])-1):
        for remote_index in range(len(compute_nodes)):
            data, target = remote_dataset[remote_index][data_index]
            models[remote_index] = update(data, target, models[remote_index], optimizers[remote_index])
        for model in models:
            model.get()
        return utils.federated_avg({
            "sm1": models[0],
            "sm2": models[1]
        })

# %%
def test(federated_model):
    federated_model.eval()
    test_loss = 0
    for data, target in test_loader:
        output = federated_model(data)
        test_loss += F.mse_loss(output.view(-1), target, reduction='sum').item()
        predection = output.data.max(1, keepdim=True)[1]
        
    test_loss /= len(test_loader.dataset)
    print('Test set: Average loss: {:.4f}'.format(test_loss))

# %%
for epoch in range(args.epochs):
    start_time = time.time()
    print(f"Epoch Number {epoch + 1}")
    federated_model = train()
    model = federated_model
    test(federated_model)
    total_time = time.time() - start_time
    print('Communication time over the network', round(total_time, 2), 's\n')
# Out:
# Epoch Number 1
# Test set: Average loss: 175.5453
# Communication time over the network 0.75 s
#
# Epoch Number 2
# Test set: Average loss: 177.2856
# Communication time over the network 0.76 s
#
# Epoch Number 3
# Test set: Average loss: 175.5752
# Communication time over the network 0.77 s
#
# Epoch Number 4
# Test set: Average loss: 176.4132
# Communication time over the network 0.73 s
#
# Epoch Number 5
# Test set: Average loss: 170.8728
# Communication time over the network 0.75 s
#
# Epoch Number 6
# Test set: Average loss: 166.7938
# Communication time over the network 0.75 s
#
# Epoch Number 7
# Test set: Average loss: 163.5324
# Communication time over the network 0.77 s
#
# Epoch Number 8
# Test set: Average loss: 171.4148
# Communication time over the network 0.75 s
#
# Epoch Number 9
# Test set: Average loss: 169.4812
# Communication time over the network 0.75 s
#
# Epoch Number 10
# Test set: Average loss: 177.3963
# Communication time over the network 0.75 s
#
# Epoch Number 11
# Test set: Average loss: 167.7639
# Communication time over the network 0.75 s
#
# Epoch Number 12
# Test set: Average loss: 171.8212
# Communication time over the network 0.76 s
#
# Epoch Number 13
# Test set: Average loss: 171.9887
# Communication time over the network 0.74 s
#
# Epoch Number 14
# Test set: Average loss: 170.5812
# Communication time over the network 0.73 s
#
# Epoch Number 15
# Test set: Average loss: 171.1690
# Communication time over the network 0.75 s
#
# Epoch Number 16
# Test set: Average loss: 169.2922
# Communication time over the network 0.76 s
#
# Epoch Number 17
# Test set: Average loss: 170.3445
# Communication time over the network 0.76 s
#
# Epoch Number 18
# Test set: Average loss: 171.9494
# Communication time over the network 0.74 s
#
# Epoch Number 19
# Test set: Average loss: 171.9687
# Communication time over the network 0.75 s
#
# Epoch Number 20
# Test set: Average loss: 171.8213
# Communication time over the network 0.73 s
#
# Epoch Number 21
# Test set: Average loss: 168.2633
# Communication time over the network 0.79 s
#
# Epoch Number 22
# Test set: Average loss: 168.7416
# Communication time over the network 0.78 s
#
# Epoch Number 23
# Test set: Average loss: 169.4778
# Communication time over the network 0.74 s
#
# Epoch Number 24
# Test set: Average loss: 167.3463
# Communication time over the network 0.74 s
#
# Epoch Number 25
# Test set: Average loss: 170.5147
# Communication time over the network 0.79 s
#
# Epoch Number 26
# Test set: Average loss: 172.5949
# Communication time over the network 0.76 s
#
# Epoch Number 27
# Test set: Average loss: 169.2145
# Communication time over the network 0.74 s
#
# Epoch Number 28
# Test set: Average loss: 165.0307
# Communication time over the network 0.74 s
#
# Epoch Number 29
# Test set: Average loss: 163.6078
# Communication time over the network 0.74 s
#
# Epoch Number 30
# Test set: Average loss: 171.0127
# Communication time over the network 0.73 s
#
# Epoch Number 31
# Test set: Average loss: 169.0762
# Communication time over the network 0.74 s
#
# Epoch Number 32
# Test set: Average loss: 164.6417
# Communication time over the network 0.75 s
#
# Epoch Number 33
# Test set: Average loss: 164.5521
# Communication time over the network 0.76 s
#
# Epoch Number 34
# Test set: Average loss: 166.6937
# Communication time over the network 0.73 s
#
# Epoch Number 35
# Test set: Average loss: 161.6539
# Communication time over the network 0.74 s
#
# Epoch Number 36
# Test set: Average loss: 167.0946
# Communication time over the network 0.76 s
#
# Epoch Number 37
# Test set: Average loss: 164.8754
# Communication time over the network 0.76 s
#
# Epoch Number 38
# Test set: Average loss: 167.1261
# Communication time over the network 0.74 s
#
# Epoch Number 39
# Test set: Average loss: 164.8448
# Communication time over the network 0.75 s
#
# Epoch Number 40
# Test set: Average loss: 160.9980
# Communication time over the network 0.76 s
#
# Epoch Number 41
# Test set: Average loss: 169.4221
# Communication time over the network 0.76 s
#
# Epoch Number 42
# Test set: Average loss: 167.1583
# Communication time over the network 0.81 s
#
# Epoch Number 43
# Test set: Average loss: 169.2483
# Communication time over the network 0.85 s
#
# Epoch Number 44
# Test set: Average loss: 164.9125
# Communication time over the network 0.8 s
#
# Epoch Number 45
# Test set: Average loss: 170.3754
# Communication time over the network 0.73 s
#
# Epoch Number 46
# Test set: Average loss: 165.9253
# Communication time over the network 0.75 s
#
# Epoch Number 47
# Test set: Average loss: 166.0325
# Communication time over the network 0.75 s
#
# Epoch Number 48
# Test set: Average loss: 169.7101
# Communication time over the network 0.75 s
#
# Epoch Number 49
# Test set: Average loss: 165.2718
# Communication time over the network 0.77 s
#
# Epoch Number 50
# Test set: Average loss: 170.2591
# Communication time over the network 0.74 s
#
# Epoch Number 51
# Test set: Average loss: 166.8742
# Communication time over the network 0.77 s
#
# Epoch Number 52
# Test set: Average loss: 165.8834
# Communication time over the network 0.75 s
#
# Epoch Number 53
# Test set: Average loss: 164.1002
# Communication time over the network 0.75 s
#
# Epoch Number 54
# Test set: Average loss: 176.3713
# Communication time over the network 0.73 s
#
# Epoch Number 55
# Test set: Average loss: 162.1561
# Communication time over the network 0.8 s
#
# Epoch Number 56
# Test set: Average loss: 164.4209
# Communication time over the network 0.81 s
#
# Epoch Number 57
# Test set: Average loss: 166.6028
# Communication time over the network 0.8 s
#
# Epoch Number 58
# Test set: Average loss: 166.5665
# Communication time over the network 0.73 s
#
# Epoch Number 59
# Test set: Average loss: 164.6282
# Communication time over the network 0.75 s
#
# Epoch Number 60
# Test set: Average loss: 160.1007
# Communication time over the network 0.75 s
#
# Epoch Number 61
# Test set: Average loss: 165.7955
# Communication time over the network 0.77 s
#
# Epoch Number 62
# Test set: Average loss: 168.2410
# Communication time over the network 0.74 s
#
# Epoch Number 63
# Test set: Average loss: 173.7252
# Communication time over the network 0.73 s
#
# Epoch Number 64
# Test set: Average loss: 165.6186
# Communication time over the network 0.78 s
#
# Epoch Number 65
# Test set: Average loss: 158.6904
# Communication time over the network 0.75 s
#
# Epoch Number 66
# Test set: Average loss: 170.1279
# Communication time over the network 0.76 s
#
# Epoch Number 67
# Test set: Average loss: 164.4641
# Communication time over the network 0.74 s
#
# Epoch Number 68
# Test set: Average loss: 163.4402
# Communication time over the network 0.75 s
#
# Epoch Number 69
# Test set: Average loss: 163.0027
# Communication time over the network 0.78 s
#
# Epoch Number 70
# Test set: Average loss: 164.9683
# Communication time over the network 0.73 s
#
# Epoch Number 71
# Test set: Average loss: 163.4056
# Communication time over the network 0.76 s
#
# Epoch Number 72
# Test set: Average loss: 163.1784
# Communication time over the network 0.78 s
#
# Epoch Number 73
# Test set: Average loss: 161.8568
# Communication time over the network 0.77 s
#
# Epoch Number 74
# Test set: Average loss: 168.8940
# Communication time over the network 0.76 s
#
# Epoch Number 75
# Test set: Average loss: 161.1333
# Communication time over the network 0.75 s
#
# Epoch Number 76
# Test set: Average loss: 164.2771
# Communication time over the network 0.77 s
#
# Epoch Number 77
# Test set: Average loss: 164.9342
# Communication time over the network 0.79 s
#
# Epoch Number 78
# Test set: Average loss: 161.7723
# Communication time over the network 0.75 s
#
# Epoch Number 79
# Test set: Average loss: 159.9623
# Communication time over the network 0.75 s
#
# Epoch Number 80
# Test set: Average loss: 157.9059
# Communication time over the network 0.75 s
#
# Epoch Number 81
# Test set: Average loss: 163.0396
# Communication time over the network 0.76 s
#
# Epoch Number 82
# Test set: Average loss: 169.7488
# Communication time over the network 0.76 s
#
# Epoch Number 83
# Test set: Average loss: 163.1150
# Communication time over the network 0.77 s
#
# Epoch Number 84
# Test set: Average loss: 162.1359
# Communication time over the network 0.74 s
#
# Epoch Number 85
# Test set: Average loss: 166.7763
# Communication time over the network 0.75 s
#
# Epoch Number 86
# Test set: Average loss: 168.1132
# Communication time over the network 0.75 s
#
# Epoch Number 87
# Test set: Average loss: 165.4085
# Communication time over the network 0.75 s
#
# Epoch Number 88
# Test set: Average loss: 163.9788
# Communication time over the network 0.75 s
#
# Epoch Number 89
# Test set: Average loss: 164.5217
# Communication time over the network 0.76 s
#
# Epoch Number 90
# Test set: Average loss: 160.9885
# Communication time over the network 0.76 s
#
# Epoch Number 91
# Test set: Average loss: 164.4696
# Communication time over the network 0.76 s
#
# Epoch Number 92
# Test set: Average loss: 160.7191
# Communication time over the network 0.76 s
#
# Epoch Number 93
# Test set: Average loss: 162.9338
# Communication time over the network 0.75 s
#
# Epoch Number 94
# Test set: Average loss: 166.5211
# Communication time over the network 0.73 s
#
# Epoch Number 95
# Test set: Average loss: 162.9835
# Communication time over the network 0.75 s
#
# Epoch Number 96
# Test set: Average loss: 169.2279
# Communication time over the network 0.74 s
#
# Epoch Number 97
# Test set: Average loss: 160.9194
# Communication time over the network 0.75 s
#
# Epoch Number 98
# Test set: Average loss: 164.9732
# Communication time over the network 0.74 s
#
# Epoch Number 99
# Test set: Average loss: 165.9608
# Communication time over the network 0.73 s
#
# Epoch Number 100
# Test set: Average loss: 162.3006
# Communication time over the network 0.74 s
#
# Epoch Number 101
# Test set: Average loss: 166.8374
# Communication time over the network 0.73 s
#
# Epoch Number 102
# Test set: Average loss: 164.1489
# Communication time over the network 0.73 s
#
# Epoch Number 103
# Test set: Average loss: 161.8614
# Communication time over the network 0.74 s
#
# Epoch Number 104
# Test set: Average loss: 162.9351
# Communication time over the network 0.76 s
#
# Epoch Number 105
# Test set: Average loss: 161.1812
# Communication time over the network 0.74 s
#
# Epoch Number 106
# Test set: Average loss: 169.7480
# Communication time over the network 0.73 s
#
# Epoch Number 107
# Test set: Average loss: 164.0574
# Communication time over the network 0.77 s
#
# Epoch Number 108
# Test set: Average loss: 162.9874
# Communication time over the network 0.76 s
#
# Epoch Number 109
# Test set: Average loss: 163.4580
# Communication time over the network 0.75 s
#
# Epoch Number 110
# Test set: Average loss: 164.8766
# Communication time over the network 0.74 s
#
# Epoch Number 111
# Test set: Average loss: 163.7116
# Communication time over the network 0.74 s
#
# Epoch Number 112
# Test set: Average loss: 161.6490
# Communication time over the network 0.75 s
#
# Epoch Number 113
# Test set: Average loss: 163.7616
# Communication time over the network 0.76 s
#
# Epoch Number 114
# Test set: Average loss: 159.2542
# Communication time over the network 0.74 s
#
# Epoch Number 115
# Test set: Average loss: 162.9534
# Communication time over the network 0.75 s
#
# Epoch Number 116
# Test set: Average loss: 161.7825
# Communication time over the network 0.74 s
#
# Epoch Number 117
# Test set: Average loss: 166.5789
# Communication time over the network 0.76 s
#
# Epoch Number 118
# Test set: Average loss: 162.6990
# Communication time over the network 0.75 s
#
# Epoch Number 119
# Test set: Average loss: 163.2271
# Communication time over the network 0.76 s
#
# Epoch Number 120
# Test set: Average loss: 165.9686
# Communication time over the network 0.75 s
#
# Epoch Number 121
# Test set: Average loss: 165.2687
# Communication time over the network 0.74 s
#
# Epoch Number 122
# Test set: Average loss: 167.1634
# Communication time over the network 0.73 s
#
# Epoch Number 123
# Test set: Average loss: 165.1656
# Communication time over the network 0.75 s
#
# Epoch Number 124
# Test set: Average loss: 164.4991
# Communication time over the network 0.72 s
#
# Epoch Number 125
# Test set: Average loss: 164.8000
# Communication time over the network 0.73 s
#
# Epoch Number 126
# Test set: Average loss: 161.3880
# Communication time over the network 0.73 s
#
# Epoch Number 127
# Test set: Average loss: 165.0638
# Communication time over the network 0.73 s
#
# Epoch Number 128
# Test set: Average loss: 160.9986
# Communication time over the network 0.75 s
#
# Epoch Number 129
# Test set: Average loss: 163.7718
# Communication time over the network 0.75 s
#
# Epoch Number 130
# Test set: Average loss: 168.4860
# Communication time over the network 0.75 s
#
# Epoch Number 131
# Test set: Average loss: 161.5686
# Communication time over the network 0.75 s
#
# Epoch Number 132
# Test set: Average loss: 159.4608
# Communication time over the network 0.76 s
#
# Epoch Number 133
# Test set: Average loss: 167.1801
# Communication time over the network 0.76 s
#
# Epoch Number 134
# Test set: Average loss: 165.2519
# Communication time over the network 0.75 s
#
# Epoch Number 135
# Test set: Average loss: 160.3136
# Communication time over the network 0.77 s
#
# Epoch Number 136
# Test set: Average loss: 160.5272
# Communication time over the network 0.75 s
#
# Epoch Number 137
# Test set: Average loss: 159.0800
# Communication time over the network 0.75 s
#
# Epoch Number 138
# Test set: Average loss: 162.6553
# Communication time over the network 0.74 s
#
# Epoch Number 139
# Test set: Average loss: 164.2039
# Communication time over the network 0.74 s
#
# Epoch Number 140
# Test set: Average loss: 160.4758
# Communication time over the network 0.77 s
#
# Epoch Number 141
# Test set: Average loss: 166.7759
# Communication time over the network 0.76 s
#
# Epoch Number 142
# Test set: Average loss: 161.2462
# Communication time over the network 0.76 s
#
# Epoch Number 143
# Test set: Average loss: 165.9082
# Communication time over the network 0.76 s
#
# Epoch Number 144
# Test set: Average loss: 165.0015
# Communication time over the network 0.79 s
#
# Epoch Number 145
# Test set: Average loss: 167.7151
# Communication time over the network 0.76 s
#
# Epoch Number 146
# Test set: Average loss: 162.2062
# Communication time over the network 0.75 s
#
# Epoch Number 147
# Test set: Average loss: 158.4385
# Communication time over the network 0.74 s
#
# Epoch Number 148
# Test set: Average loss: 166.7086
# Communication time over the network 0.76 s
#
# Epoch Number 149
# Test set: Average loss: 162.7146
# Communication time over the network 0.76 s
#
# Epoch Number 150
# Test set: Average loss: 164.3611
# Communication time over the network 0.76 s
#
# Epoch Number 151
# Test set: Average loss: 161.4671
# Communication time over the network 0.76 s
#
# Epoch Number 152
# Test set: Average loss: 164.3529
# Communication time over the network 0.76 s
#
# Epoch Number 153
# Test set: Average loss: 169.8433
# Communication time over the network 0.77 s
#
# Epoch Number 154
# Test set: Average loss: 160.1145
# Communication time over the network 0.76 s
#
# Epoch Number 155
# Test set: Average loss: 164.9368
# Communication time over the network 0.72 s
#
# Epoch Number 156
# Test set: Average loss: 160.8829
# Communication time over the network 0.73 s
#
# Epoch Number 157
# Test set: Average loss: 165.6825
# Communication time over the network 0.73 s
#
# Epoch Number 158
# Test set: Average loss: 164.5007
# Communication time over the network 0.74 s
#
# Epoch Number 159
# Test set: Average loss: 169.6348
# Communication time over the network 0.74 s
#
# Epoch Number 160
# Test set: Average loss: 161.2177
# Communication time over the network 0.77 s
#
# Epoch Number 161
# Test set: Average loss: 165.0702
# Communication time over the network 0.72 s
#
# Epoch Number 162
# Test set: Average loss: 163.9815
# Communication time over the network 0.73 s
#
# Epoch Number 163
# Test set: Average loss: 164.6749
# Communication time over the network 0.73 s
#
# Epoch Number 164
# Test set: Average loss: 166.5922
# Communication time over the network 0.74 s
#
# Epoch Number 165
# Test set: Average loss: 161.2886
# Communication time over the network 0.72 s
#
# Epoch Number 166
# Test set: Average loss: 165.2609
# Communication time over the network 0.73 s
#
# Epoch Number 167
# Test set: Average loss: 163.2989
# Communication time over the network 0.73 s
#
# Epoch Number 168
# Test set: Average loss: 159.0109
# Communication time over the network 0.75 s
#
# Epoch Number 169
# Test set: Average loss: 159.5261
# Communication time over the network 0.74 s
#
# Epoch Number 170
# Test set: Average loss: 165.1256
# Communication time over the network 0.73 s
#
# Epoch Number 171
# Test set: Average loss: 168.5885
# Communication time over the network 0.72 s
#
# Epoch Number 172
# Test set: Average loss: 163.4788
# Communication time over the network 0.75 s
#
# Epoch Number 173
# Test set: Average loss: 160.1846
# Communication time over the network 0.74 s
#
# Epoch Number 174
# Test set: Average loss: 163.0407
# Communication time over the network 0.76 s
#
# Epoch Number 175
# Test set: Average loss: 162.8503
# Communication time over the network 0.76 s
#
# Epoch Number 176
# Test set: Average loss: 162.9019
# Communication time over the network 0.74 s
#
# Epoch Number 177
# Test set: Average loss: 164.2877
# Communication time over the network 0.75 s
#
# Epoch Number 178
# Test set: Average loss: 159.9220
# Communication time over the network 0.76 s
#
# Epoch Number 179
# Test set: Average loss: 164.7804
# Communication time over the network 0.75 s
#
# Epoch Number 180
# Test set: Average loss: 163.3356
# Communication time over the network 0.75 s
#
# Epoch Number 181
# Test set: Average loss: 163.6225
# Communication time over the network 0.72 s
#
# Epoch Number 182
# Test set: Average loss: 162.2101
# Communication time over the network 0.75 s
#
# Epoch Number 183
# Test set: Average loss: 158.7559
# Communication time over the network 0.74 s
#
# Epoch Number 184
# Test set: Average loss: 163.3215
# Communication time over the network 0.74 s
#
# Epoch Number 185
# Test set: Average loss: 167.4714
# Communication time over the network 0.75 s
#
# Epoch Number 186
# Test set: Average loss: 159.9323
# Communication time over the network 0.74 s
#
# Epoch Number 187
# Test set: Average loss: 159.4661
# Communication time over the network 0.74 s
#
# Epoch Number 188
# Test set: Average loss: 164.0051
# Communication time over the network 0.77 s
#
# Epoch Number 189
# Test set: Average loss: 163.9255
# Communication time over the network 0.77 s
#
# Epoch Number 190
# Test set: Average loss: 167.2197
# Communication time over the network 0.74 s
#
# Epoch Number 191
# Test set: Average loss: 159.4311
# Communication time over the network 0.77 s
#
# Epoch Number 192
# Test set: Average loss: 159.0642
# Communication time over the network 0.75 s
#
# Epoch Number 193
# Test set: Average loss: 166.8160
# Communication time over the network 0.74 s
#
# Epoch Number 194
# Test set: Average loss: 164.0193
# Communication time over the network 0.73 s
#
# Epoch Number 195
# Test set: Average loss: 162.3472
# Communication time over the network 0.74 s
#
# Epoch Number 196
# Test set: Average loss: 160.0382
# Communication time over the network 0.72 s
#
# Epoch Number 197
# Test set: Average loss: 164.3013
# Communication time over the network 0.74 s
#
# Epoch Number 198
# Test set: Average loss: 162.9056
# Communication time over the network 0.74 s
#
# Epoch Number 199
# Test set: Average loss: 162.2975
# Communication time over the network 0.76 s
#
# Epoch Number 200
# Test set: Average loss: 158.1439
# Communication time over the network 0.74 s
