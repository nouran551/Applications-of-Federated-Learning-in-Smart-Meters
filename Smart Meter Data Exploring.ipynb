# %%
import pandas as pd

# %%
daily_data = pd.read_csv('Documents/Smart meters in London/daily_dataset.csv/daily_dataset.csv')
daily_data.head(20)
# Out:
#         LCLid         day  energy_median  energy_mean  energy_max  \
# 0   MAC000131  2011-12-15         0.4850     0.432045       0.868
# 1   MAC000131  2011-12-16         0.1415     0.296167       1.116
# 2   MAC000131  2011-12-17         0.1015     0.189812       0.685
# 3   MAC000131  2011-12-18         0.1140     0.218979       0.676
# 4   MAC000131  2011-12-19         0.1910     0.325979       0.788
# 5   MAC000131  2011-12-20         0.2180     0.357500       1.077
# 6   MAC000131  2011-12-21         0.1305     0.235083       0.705
# 7   MAC000131  2011-12-22         0.0890     0.221354       1.094
# 8   MAC000131  2011-12-23         0.1605     0.291125       0.749
# 9   MAC000131  2011-12-24         0.1070     0.169000       0.613
# 10  MAC000131  2011-12-25         0.2175     0.339188       0.866
# 11  MAC000131  2011-12-26         0.1495     0.261708       0.838
# 12  MAC000131  2011-12-27         0.1430     0.274000       0.778
# ...

# %%
#block_0.csv to block_111.csv
daily_data_block111 = pd.read_csv('Documents/Smart meters in London/daily_dataset/daily_dataset/block_111.csv')
daily_data_block111.head(50)
# Out:
#         LCLid         day  energy_median  energy_mean  energy_max  \
# 0   MAC000023  2011-12-07         0.4070     0.431778       0.863
# 1   MAC000023  2011-12-08         0.3525     0.448375       2.465
# 2   MAC000023  2011-12-09         0.2905     0.303417       0.977
# 3   MAC000023  2011-12-10         0.1865     0.229833       0.868
# 4   MAC000023  2011-12-11         0.2760     0.391438       1.903
# 5   MAC000023  2011-12-12         0.3050     0.403833       1.561
# 6   MAC000023  2011-12-13         0.1895     0.276500       1.086
# 7   MAC000023  2011-12-14         0.1585     0.373104       2.022
# 8   MAC000023  2011-12-15         0.3940     0.536646       1.784
# 9   MAC000023  2011-12-16         0.1375     0.237854       0.861
# 10  MAC000023  2011-12-17         0.2975     0.377813       1.437
# 11  MAC000023  2011-12-18         0.5520     0.576625       1.784
# 12  MAC000023  2011-12-19         0.4705     0.538146       1.723
# ...

# %%
daily_data_block111.tail(50)
# Out:
#           LCLid         day  energy_median  energy_mean  energy_max  \
# 9858  MAC004828  2014-01-10         0.0025     0.012833       0.046
# 9859  MAC004828  2014-01-11         0.0110     0.015354       0.048
# 9860  MAC004828  2014-01-12         0.0015     0.012771       0.046
# 9861  MAC004828  2014-01-13         0.0125     0.014917       0.046
# 9862  MAC004828  2014-01-14         0.0200     0.033521       0.146
# 9863  MAC004828  2014-01-15         0.0080     0.015000       0.047
# 9864  MAC004828  2014-01-16         0.0040     0.013875       0.047
# 9865  MAC004828  2014-01-17         0.0160     0.015271       0.047
# 9866  MAC004828  2014-01-18         0.0045     0.013979       0.046
# 9867  MAC004828  2014-01-19         0.0045     0.013958       0.047
# 9868  MAC004828  2014-01-20         0.0055     0.014438       0.048
# 9869  MAC004828  2014-01-21         0.0090     0.019229       0.088
# 9870  MAC004828  2014-01-22         0.0020     0.012688       0.047
# ...

# %%
daily_data_block111.shape
# Out:
# (9908, 9)

# %%
#block_0.csv to block_111.csv

halfhourly_dataset_block_111 = pd.read_csv('Documents/Smart meters in London/halfhourly_dataset/halfhourly_dataset/block_111.csv')
halfhourly_dataset_block_111.head(20)
# Out:
#         LCLid                         tstp energy(kWh/hh)
# 0   MAC000023  2011-12-07 10:30:00.0000000          0.54
# 1   MAC000023  2011-12-07 11:00:00.0000000         0.863
# 2   MAC000023  2011-12-07 11:30:00.0000000         0.475
# 3   MAC000023  2011-12-07 12:00:00.0000000         0.495
# 4   MAC000023  2011-12-07 12:30:00.0000000         0.341
# 5   MAC000023  2011-12-07 13:00:00.0000000         0.625
# 6   MAC000023  2011-12-07 13:30:00.0000000         0.505
# 7   MAC000023  2011-12-07 14:00:00.0000000         0.371
# 8   MAC000023  2011-12-07 14:30:00.0000000         0.299
# 9   MAC000023  2011-12-07 15:00:00.0000000         0.098
# 10  MAC000023  2011-12-07 15:30:00.0000000         0.109
# 11  MAC000023  2011-12-07 16:00:00.0000000         0.129
# 12  MAC000023  2011-12-07 16:30:00.0000000         0.206
# 13  MAC000023  2011-12-07 17:00:00.0000000         0.359
# 14  MAC000023  2011-12-07 17:30:00.0000000         0.367
# ...

# %%
halfhourly_dataset_block_111.shape
# Out:
# (472497, 3)

# %%
#block_0.csv to block_111.csv

hhblock_dataset= pd.read_csv('Documents/Smart meters in London/hhblock_dataset/hhblock_dataset/block_111.csv')
hhblock_dataset.head(50)
# Out:
#         LCLid         day   hh_0   hh_1   hh_2   hh_3   hh_4   hh_5   hh_6  \
# 0   MAC000023  2011-12-08  0.312  0.312  0.349  0.206  0.063  0.045  0.046
# 1   MAC000023  2011-12-09  0.154  0.102  0.044  0.044  0.045  0.098  0.099
# 2   MAC000023  2011-12-10  0.105  0.063  0.052  0.045  0.048  0.108  0.095
# 3   MAC000023  2011-12-11  0.799  0.539  0.286  0.457  0.161  0.038  0.041
# 4   MAC000023  2011-12-12  0.200  0.110  0.099  0.044  0.040  0.039  0.065
# 5   MAC000023  2011-12-13  0.123  0.081  0.047  0.043  0.044  0.100  0.097
# 6   MAC000023  2011-12-14  0.111  0.046  0.045  0.050  0.111  0.096  0.042
# 7   MAC000023  2011-12-15  0.175  0.156  0.112  0.110  0.129  0.138  0.166
# 8   MAC000023  2011-12-16  0.134  0.091  0.048  0.045  0.065  0.108  0.085
# 9   MAC000023  2011-12-17  0.048  0.067  0.102  0.069  0.044  0.044  0.045
# 10  MAC000023  2011-12-18  0.275  0.178  0.096  0.040  0.037  0.045  0.045
# ...

# %%
hhblock_dataset.shape
# Out:
# (9740, 50)

# %%
hhblock_dataset_11= pd.read_csv('Documents/Smart meters in London/hhblock_dataset/hhblock_dataset/block_11.csv')
hhblock_dataset_11.shape
# Out:
# (32361, 50)

# %%
acorn_details = pd.read_csv('Documents/Smart meters in London/acorn_details.csv', encoding= 'unicode_escape')
acorn_details.head(20)
# Out:
#    MAIN CATEGORIES        CATEGORIES  \
# 0       POPULATION               Age
# 1       POPULATION               Age
# 2       POPULATION               Age
# 3       POPULATION               Age
# 4       POPULATION               Age
# 5       POPULATION               Age
# 6       POPULATION               Age
# 7       POPULATION               Age
# 8       POPULATION         Geography
# 9       POPULATION         Geography
# 10      POPULATION         Geography
# 11      POPULATION         Geography
# 12      POPULATION         Ethnicity
# 13      POPULATION         Ethnicity
# 14      POPULATION         Ethnicity
# 15      POPULATION         Ethnicity
# 16      POPULATION         Ethnicity
# 17      POPULATION  Country of Birth
# 18      POPULATION  Country of Birth
# 19      POPULATION  Country of Birth
#
#                                            REFERENCE  ACORN-A  ACORN-B  \
# 0                                            Age 0-4     77.0     83.0
# ...

# %%
acorn_details.shape
# Out:
# (826, 20)

# %%
informations_households = pd.read_csv('Documents/Smart meters in London/informations_households.csv')
informations_households.head(20)
# Out:
#         LCLid stdorToU    Acorn Acorn_grouped     file
# 0   MAC005492      ToU   ACORN-        ACORN-  block_0
# 1   MAC001074      ToU   ACORN-        ACORN-  block_0
# 2   MAC000002      Std  ACORN-A      Affluent  block_0
# 3   MAC003613      Std  ACORN-A      Affluent  block_0
# 4   MAC003597      Std  ACORN-A      Affluent  block_0
# 5   MAC003579      Std  ACORN-A      Affluent  block_0
# 6   MAC003566      Std  ACORN-A      Affluent  block_0
# 7   MAC003557      Std  ACORN-A      Affluent  block_0
# 8   MAC003553      Std  ACORN-A      Affluent  block_0
# 9   MAC003482      Std  ACORN-A      Affluent  block_0
# 10  MAC003463      Std  ACORN-A      Affluent  block_0
# 11  MAC003449      Std  ACORN-A      Affluent  block_0
# 12  MAC003428      Std  ACORN-A      Affluent  block_0
# 13  MAC003423      Std  ACORN-A      Affluent  block_0
# 14  MAC003422      Std  ACORN-A      Affluent  block_0
# 15  MAC003400      Std  ACORN-A      Affluent  block_0
# ...

# %%
informations_households.shape
# Out:
# (5566, 5)

# %%
informations_households.Acorn.unique()
# Out:
# array(['ACORN-', 'ACORN-A', 'ACORN-B', 'ACORN-C', 'ACORN-D', 'ACORN-E',
#        'ACORN-F', 'ACORN-G', 'ACORN-H', 'ACORN-I', 'ACORN-J', 'ACORN-K',
#        'ACORN-L', 'ACORN-M', 'ACORN-N', 'ACORN-O', 'ACORN-P', 'ACORN-Q',
#        'ACORN-U'], dtype=object)

# %%
informations_households.Acorn_grouped.unique()
# Out:
# array(['ACORN-', 'Affluent', 'Comfortable', 'Adversity', 'ACORN-U'],
#       dtype=object)

# %%
uk_bank_holidays = pd.read_csv('Documents/Smart meters in London/uk_bank_holidays.csv')
uk_bank_holidays.head(20)
# Out:
#    Bank holidays                                          Type
# 0     2012-12-26                                    Boxing Day
# 1     2012-12-25                                 Christmas Day
# 2     2012-08-27                           Summer bank holiday
# 3     2012-05-06  Queen?s Diamond Jubilee (extra bank holiday)
# 4     2012-04-06          Spring bank holiday (substitute day)
# 5     2012-07-05                        Early May bank holiday
# 6     2012-09-04                                 Easter Monday
# 7     2012-06-04                                   Good Friday
# 8     2012-02-01               New Year?s Day (substitute day)
# 9     2013-12-26                                    Boxing Day
# 10    2013-12-25                                 Christmas Day
# 11    2013-08-26                           Summer bank holiday
# 12    2013-05-27                           Spring bank holiday
# 13    2013-06-05                        Early May bank holiday
# ...

# %%
uk_bank_holidays.shape
# Out:
# (25, 2)

# %%
weather_daily_darksky = pd.read_csv('Documents/Smart meters in London/weather_daily_darksky.csv')
weather_daily_darksky.head()
# Out:
#    temperatureMax   temperatureMaxTime  windBearing                 icon  \
# 0           11.96  2011-11-11 23:00:00          123                  fog
# 1            8.59  2011-12-11 14:00:00          198    partly-cloudy-day
# 2           10.33  2011-12-27 02:00:00          225    partly-cloudy-day
# 3            8.07  2011-12-02 23:00:00          232                 wind
# 4            8.22  2011-12-24 23:00:00          252  partly-cloudy-night
#
#    dewPoint   temperatureMinTime  cloudCover  windSpeed  pressure  \
# 0      9.40  2011-11-11 07:00:00        0.79       3.88   1016.08
# 1      4.49  2011-12-11 01:00:00        0.56       3.94   1007.71
# 2      5.47  2011-12-27 23:00:00        0.85       3.54   1032.76
# 3      3.69  2011-12-02 07:00:00        0.32       3.00   1012.12
# 4      2.79  2011-12-24 07:00:00        0.37       4.46   1028.17
#
#   apparentTemperatureMinTime  ...  temperatureHigh          sunriseTime  \
# ...

# %%
weather_daily_darksky.shape
# Out:
# (882, 32)

# %%
weather_hourly_darksky = pd.read_csv('Documents/Smart meters in London/weather_hourly_darksky.csv')
weather_hourly_darksky.head(20)
# Out:
#     visibility  windBearing  temperature                 time  dewPoint  \
# 0         5.97          104        10.24  2011-11-11 00:00:00      8.86
# 1         4.88           99         9.76  2011-11-11 01:00:00      8.83
# 2         3.70           98         9.46  2011-11-11 02:00:00      8.79
# 3         3.12           99         9.23  2011-11-11 03:00:00      8.63
# 4         1.85          111         9.26  2011-11-11 04:00:00      9.21
# 5         1.96          115         9.33  2011-11-11 05:00:00      8.87
# 6         1.30          118         9.31  2011-11-11 06:00:00      8.82
# 7         1.22          114         8.85  2011-11-11 07:00:00      8.69
# 8         1.40          120         9.13  2011-11-11 08:00:00      8.75
# 9         1.38          121         9.23  2011-11-11 09:00:00      8.70
# 10        1.35          115         9.21  2011-11-11 10:00:00      8.76
# 11        1.72          127         9.78  2011-11-11 11:00:00      9.23
# ...

# %%
weather_hourly_darksky.shape
# Out:
# (21165, 12)

# %%
ls
# Out:
#  anaconda3/   packages.microsoft.gpg            snap/
#  Desktop/     Pictures/                         Templates/
#  Documents/   Public/                           Videos/
#  Downloads/   slack-3.4.0-0.1.fc21.x86_64.rpm
#  Music/      'SM Data Visualization.ipynb'

# %%
ls Documnets/
# Out:
# ls: cannot access 'Documnets/': No such file or directory

# %%
ls
# Out:
#  anaconda3/   packages.microsoft.gpg            snap/
#  Desktop/     Pictures/                         Templates/
#  Documents/   Public/                           Videos/
#  Downloads/   slack-3.4.0-0.1.fc21.x86_64.rpm
#  Music/      'SM Data Visualization.ipynb'

# %%
ls Documents/'Smart meters in London'/daily_dataset.csv/
# Out:
# daily_dataset.csv
